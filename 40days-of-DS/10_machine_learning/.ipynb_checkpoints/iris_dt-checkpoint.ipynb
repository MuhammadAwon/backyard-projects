# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
# Load data
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Split data
X = df.iloc[:,:-1]
y = df.iloc[:,-1:]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Create, fit and plot dt model
from sklearn.tree import plot_tree

model = DecisionTreeClassifier().fit(X, y)
plot_tree(model, filled=True)
plt.title('Decision tree trained model on Iris data')
plt.show()

# %%
# Save figure in PNG
plot_tree(model, filled=True)
plt.title('Decision tree trained model on Iris data')
plt.savefig('png_dt', format='png', dpi=1200)
plt.show()

# %%
# Save figure in PDF
plot_tree(model, filled=True)
plt.title('Decision tree trained model on Iris data')
plt.savefig('pdf_dt.pdf', dpi=1200)
plt.show()

# %%
fig.savefig('/tmp/foo.tiff', dpi=600, format="tiff",
            pil_kwargs={"compression": "tiff_lzw"})

# %%
# Save figure in TIFF
plot_tree(model, filled=True)
plt.title('Decision tree trained model on Iris data')
plt.savefig('tiff_dt.tiff', dpi=1200, format='tiff')
plt.show()
